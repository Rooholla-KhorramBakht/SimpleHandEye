# %% [markdown]
# # AX=YB
# This notebook shows the process of calibrating the extrinsic parameters between the Vicon marker coordinate frame installed on an object with respect to the object CAD coordinate frame. We use the ICG 3D tracker algorithm to track the 3D pose of the object through its pointcloud observation and the ROS2 vicon bridge to get the pose of the markers installed on it.

# %% [markdown]
# ## Instantiate the Interfaces
# ### ROS2

# %%
from SimpleHandEye.interfaces.cameras import RealSenseCamera
import cv2

# def showImage(color_frame, depth_frame, ir1_frame, ir2_frame):
#     cv2.imshow('image', ir1_frame)
#     cv2.waitKey(16)

# camera_reader = RealSenseCamera(callback_fn=showImage, emitter_enabled=False)
camera_reader = RealSenseCamera(emitter_enabled=False)

intrinsics_params = camera_reader.getIntrinsics()
K = intrinsics_params['IR1']['K']
D = intrinsics_params['IR1']['D']
# Out:
# Enabling streams for camera:  142422250881
# Warning: HD color fps cannot be higher than 30
# Warning: HD depth/infrared fps cannot be higher than 30

# %%
from SimpleHandEye.interfaces.ros2 import ROS2ExecutorManager, ROS2CameraReader, ROS2TFInterface
import rclpy
rclpy.init()    
executor_manager = ROS2ExecutorManager()
# camera_reader = ROS2CameraReader('/d455_front/infra1/image_rect_raw', camera_info_topic='/d455_front/infra1/camera_info', node_name='camera_reader')
vicon_sensor = ROS2TFInterface('vicon/GO2/GO2', 'vicon/CALIB_BOARD/CALIB_BOARD', node_name='vicon_sensor_node')
# apriltag_sensor = ROS2TFInterface('d455_front_infra1_optical_frame', 'object', node_name='apriltag_sensor_node')
# executor_manager.add_node(camera_reader)
executor_manager.add_node(vicon_sensor)
# executor_manager.add_node(apriltag_sensor)
executor_manager.start()

# %%
vicon_sensor.get_pose()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 vicon_sensor.get_pose()
#
# NameError: name 'vicon_sensor' is not defined

# %% [markdown]
# ### April-Tag Tracker

# %%
from SimpleHandEye.interfaces.apriltag import ApriltagTracker
tracker = ApriltagTracker(tag_size=0.172,
                          intrinsic_matrix=K,
                          distortion_coeffs=D)

tracker.getPose(camera_reader.color_frame, tag_id=0)

# %%
vicon_sensor.get_pose(), tracker.getPose(camera_reader.color_frame, tag_id=0)
# Out:
# (array([[-0.747121  , -0.06024103, -0.66195259,  0.22131879],
#         [-0.25140242, -0.89629309,  0.36531565, -1.1306627 ],
#         [-0.61531052,  0.43935148,  0.65449465,  0.34094415],
#         [ 0.        ,  0.        ,  0.        ,  1.        ]]),
#  array([[-0.78249885,  0.62133697, -0.04044654, -0.37483482],
#         [-0.61804013, -0.78295411, -0.07077616,  0.09657575],
#         [-0.07564363, -0.03038468,  0.99667187,  0.76575749],
#         [ 0.        ,  0.        ,  0.        ,  1.        ]]))

# %% [markdown]
# ## Instantiate the Solver

# %%
from SimpleHandEye.solvers import OpenCVSolver
solver = OpenCVSolver()

# %% [markdown]
# ## Collect The Calibration Dataset

# %%
import ipywidgets as widgets
import numpy as np
from IPython.display import display
from pprint import pprint
from IPython.display import clear_output
np.set_printoptions(suppress=True, precision=3)

# The dataset
A_list = []
B_list = []
apriltag_info = []
apriltag_imgs_raw = []
apriltag_imgs_udist = []
B_list_tf = []
def on_sample_clicked(b):
    img = camera_reader.ir1_frame
    info = tracker.getPoseAndCorners(img, tag_id=0)
    if info is None:
        return
    A = vicon_sensor.get_pose()
    B = info['pose']
    apriltag_info.append(info)
    apriltag_imgs_raw.append(img)
    apriltag_imgs_udist.append(tracker.undistortImage(img))
    print("A=")
    pprint(A)
    print("B=")
    pprint(B)
    # if A is not None and B is not None:
    A_list.append(A)
    B_list.append(B)
    print("*************")

def on_compute_clicked(b):
    try:
        X,Y = solver.solve(A_list, B_list)
        clear_output(wait=True)
        print("X=")
        pprint(X)
        print("Y=")
        pprint(Y)
    except:
        print("Bad dataset, please record again")
        A_list.clear()
        B_list.clear()
        B_list_tf.clear()
        

sample_button = widgets.Button(description="Sample")
compute_button = widgets.Button(description="Compute")

sample_button.on_click(on_sample_clicked)
compute_button.on_click(on_compute_clicked)
display(sample_button)
display(compute_button)
# Out:
# Button(description='Sample', style=ButtonStyle())
# Button(description='Compute', style=ButtonStyle())
# A=
# array([[ 0.966, -0.218, -0.141,  0.227],
#        [-0.249, -0.933, -0.261, -0.968],
#        [-0.075,  0.287, -0.955,  0.113],
#        [ 0.   ,  0.   ,  0.   ,  1.   ]])
# B=
# array([[ 0.008, -0.999, -0.031, -0.034],
#        [ 0.988,  0.012, -0.155, -0.159],
#        [ 0.156, -0.03 ,  0.987,  0.537],
#        [ 0.   ,  0.   ,  0.   ,  1.   ]])
# *************
# A=
# array([[ 0.906, -0.407, -0.116,  0.234],
#        [-0.423, -0.869, -0.257, -0.906],
#        [ 0.004,  0.282, -0.959,  0.099],
#        [ 0.   ,  0.   ,  0.   ,  1.   ]])
# B=
# array([[ 0.009, -1.   , -0.   , -0.035],
#        [ 0.939,  0.009, -0.345, -0.134],
#        [ 0.345,  0.003,  0.939,  0.433],
#        [ 0.   ,  0.   ,  0.   ,  1.   ]])
# *************
# A=
# array([[ 0.935,  0.29 , -0.206,  0.205],
#        [ 0.237, -0.94 , -0.246, -1.136],
#        [-0.265,  0.181, -0.947,  0.091],
#        [ 0.   ,  0.   ,  0.   ,  1.   ]])
# B=
# array([[ 0.001, -1.   , -0.012, -0.031],
#        [ 0.926, -0.004,  0.377, -0.125],
#        [-0.377, -0.011,  0.926,  0.806],
#        [ 0.   ,  0.   ,  0.   ,  1.   ]])
# *************
# A=
# array([[ 0.609, -0.621, -0.494,  0.257],
#        [-0.667, -0.738,  0.104, -1.01 ],
#        [-0.429,  0.266, -0.863,  0.214],
#        [ 0.   ,  0.   ,  0.   ,  1.   ]])
# B=
# array([[-0.44 , -0.85 ,  0.29 , -0.027],
#        [ 0.74 , -0.526, -0.419, -0.08 ],
#        [ 0.509,  0.03 ,  0.86 ,  0.498],
#        [ 0.   ,  0.   ,  0.   ,  1.   ]])
# *************
# A=
# array([[ 0.76 , -0.504, -0.411, -0.038],
#        [-0.533, -0.845,  0.052, -1.089],
#        [-0.373,  0.18 , -0.91 ,  0.212],
#        [ 0.   ,  0.   ,  0.   ,  1.   ]])
# B=
# array([[-0.331, -0.908,  0.255,  0.255],
#        [ 0.862, -0.401, -0.31 , -0.127],
#        [ 0.384,  0.117,  0.916,  0.611],
#        [ 0.   ,  0.   ,  0.   ,  1.   ]])
# *************
# A=
# array([[ 0.877,  0.385, -0.288, -0.032],
#        [ 0.283, -0.898, -0.338, -1.125],
#        [-0.389,  0.214, -0.896,  0.109],
#        [ 0.   ,  0.   ,  0.   ,  1.   ]])
# B=
# array([[-0.061, -0.992, -0.114,  0.22 ],
#        [ 0.876, -0.108,  0.469, -0.104],
#        [-0.478, -0.071,  0.876,  0.859],
#        [ 0.   ,  0.   ,  0.   ,  1.   ]])
# *************

# %%
X, Y = solver.solve(A_list, B_list)

# %%
for i in range(len(A_list)):
    print((A_list[i]@X@np.linalg.inv(Y@B_list[i]))[:3,-1])
# Out:
# [ 0.096  0.096 -0.078]
# [ 0.103  0.175 -0.097]
# [ 0.128 -0.066  0.026]
# [ 0.02  -0.144 -0.151]
# [-0.272 -0.089  0.268]
# [-0.098  0.015  0.027]

# %%
import pickle
with open('b1-d455-dataset.pkl', 'wb') as f:
    data = {
        'A_list': A_list,
        'B_list': B_list,
        'B_list_tf': B_list_tf,
        'apriltag_info': apriltag_info,
        'apriltag_imgs_raw': apriltag_imgs_raw,
        'apriltag_imgs_udist': apriltag_imgs_udist,
        'camera_matrix': K, 
        'distortion_coeffs': D,
        'X': X,
        'Y': Y
    }
    pickle.dump(data, f)

# %% [markdown]
# ## Export the Result

# %%
wall_T_tag = X
world_T_camera = Y

# %%
from SimpleHandEye.exporters import export2ROS
export2ROS(wall_T_tag, 'vicon/wall/wall', 'tag', 'wall_T_tag_publisher.launch')
export2ROS(world_T_camera, 'vicon/world', 'camera', 'world_T_camera_publisher.launch')

# %%
D
# Out:
# array([0., 0., 0., 0., 0.])

# %% [markdown]
# # Reprojection Error Minimization

# %%
import symforce
symforce.set_epsilon_to_symbol()
import symforce.symbolic as sf 
import numpy as np
import pickle 
from symforce.opt.optimizer import Optimizer
from symforce.values import Values
from symforce.opt.factor import Factor
import time


with open('b1-d455-dataset.pkl', 'rb') as f:
    data = pickle.load(f)

pix_ps = np.vstack([info['corners'][np.newaxis,...] for info in data['apriltag_info']]).tolist()

# %%
tag_size = 0.172
tag_ps = np.vstack(len(data['A_list'])*[[np.array([[-tag_size/2, tag_size/2, 0],
                                [ tag_size/2, tag_size/2, 0],
                                [ tag_size/2, -tag_size/2, 0],
                                [-tag_size/2,  -tag_size/2, 0]])]]).tolist()

# %%
A = [T for T in data['A_list']]
B = [T for T in data['B_list']]
Y = data['Y']
X = data['X']

# %%
from SimpleHandEye.optimizers import AXYBReprojectionOptimizer
solver = AXYBReprojectionOptimizer(camera_T_tag='B', camera_matrix=data['camera_matrix'])

# %%
class AXYBReprojectionOptimizer():
    def __init__(self, camera_T_tag = 'A', camera_matrix = None, distortion_coeffs= None):
        """
        A class to optimize the reprojection error of the AXYB calibration method
        @param camera_T_tag: which transformation represents the camera pose tracker, 'A' or 'B' or 'A_inv' or 'B_inv'
        @param camera_matrix: the camera intrinsic matrix
        @param distortion_coeffs: the camera distortion coefficients
        """
        assert camera_T_tag in ['A', 'B', 'A_inv', 'B_inv'], "camera_T_tag must be 'A' or 'B' or 'A_inv' or 'B_inv'"
        self.camera_T_tag = camera_T_tag
        self.camera_matrix = camera_matrix
        self.distortion_coeffs = distortion_coeffs
        self.result = None

    def reprojectionResidual(self_obj,
                            A: sf.Pose3,
                            X: sf.Pose3,
                            Y: sf.Pose3,
                            B: sf.Pose3,
                            tag_p: sf.V3,
                            pix_p: sf.V2,
                            K: sf.Matrix33,
                            epsilon:sf.Scalar):
        """
        The reprojection residual function
        @param A: the pose A in the AX=YB equation
        @param X: the pose X in the AX=YB equation
        @param Y: the pose Y in the AX=YB equation
        @param B: the pose B in the AX=YB equation
        @param tag_ps: the tag position in the tag frame for each image frame
        @param pix_ps: the measured image points for each image frame
        @param K: the camera intrinsic matrix
        @param epsilon: a small value to avoid division by zero
        @return: the reprojection residual
        """
        
        if self_obj.camera_T_tag == 'A':
            camera_T_tag = X.inverse()*Y*B
        elif self_obj.camera_T_tag == 'B':
            camera_T_tag = Y.inverse()*A*X
        elif self_obj.camera_T_tag == 'A_inv':
            camera_T_tag = (X.inverse()*Y*B).inverse()
        elif self_obj.camera_T_tag == 'B_inv':
            camera_T_tag = (Y.inverse()*A*X).inverse()
        
        z_hat = K*(camera_T_tag*sf.V3(tag_p))
        z_hat = z_hat/(z_hat[2]+epsilon)
        return sf.V1((z_hat[:2]-pix_p).norm(epsilon=epsilon)) 

    def solve(self, A: list, 
                    X: np.array, 
                    Y: np.array, 
                    B: list, 
                    tag_ps: list, 
                    pix_ps: list):
        """
        Solve the AX=YB equation
        @param A: The list of A 4x4 poses in the AX=YB equation
        @param X: the 4x4 pose X in the AX=YB equation
        @param Y: the 4x4 pose Y in the AX=YB equation
        @param B: The list of 4x4 B poses in the AX=YB equation
        @param tag_ps: the tag position in the tag frame (nxm where n is the number of poses and m is the number of correspondences per pose)
        @param pix_ps: the measured image points (nxm where n is the number of poses and m is the number of correspondences per pose)
        @return: the optimized X and Y poses
        """
        assert len(A) == len(B), "Measurement lists must have the same length"
        assert len(A) > 0, "All lists must have at least one element"
        assert self.camera_matrix is not None, "camera_matrix must be set"

        initial_values = Values(
                                A = [sf.Pose3(R = sf.Rot3.from_rotation_matrix(T[0:3,0:3]),
                                                                t = sf.V3(T[0:3,-1]))\
                                                                for T in A ],

                                B = [sf.Pose3(R = sf.Rot3.from_rotation_matrix(T[0:3,0:3]),
                                                                t = sf.V3(T[0:3,-1]))\
                                                                for T in B ],
                                
                                Y = sf.Pose3(R = sf.Rot3.from_rotation_matrix(Y[0:3,0:3]),
                                             t = sf.V3(Y[0:3,-1])),

                                X = sf.Pose3(R = sf.Rot3.from_rotation_matrix(X[0:3,0:3]),
                                                        t = sf.V3(X[0:3,-1])),
                                K = sf.Matrix33(self.camera_matrix),
                                pix_ps = [[sf.V2(pix) for pix in pixels] for pixels in pix_ps],
                                tag_ps = [[sf.V3(c) for c in corners] for corners in tag_ps],
                                epsilon = sf.numeric_epsilon,
                                )  
        self.initial_values = initial_values

        factors = []
        i=0
        for i in range(len(pix_ps)):
            for j in range(len(pix_ps[i])):
                factors.append(
                            Factor(
                                    residual=self.reprojectionResidual,
                                    keys=[ 
                                        f"A[{i}]",
                                        f"X",
                                        f"Y",
                                        f"B[{i}]",
                                        f'tag_ps[{i}][{j}]',
                                        f'pix_ps[{i}][{j}]',
                                        "K",
                                        "epsilon"],
                                )
                            ) 
                # print(self.reprojectionResidual(
                #     initial_values[f"A[{i}]"],
                #     initial_values[f"X"],
                #     initial_values[f"Y"],
                #     initial_values[f"B[{i}]"],
                #     initial_values[f"tag_ps[{i}][{j}]"],
                #     initial_values[f"pix_ps[{i}][{j}]"],
                #     initial_values[f"K"],
                #     initial_values[f"epsilon"],
                    
                # ))
        if self.camera_T_tag in ['B', 'B_inv']:
            optimizer = Optimizer(
                factors=factors,
                optimized_keys=["X", "Y"]+ \
                               [f'B[{i}]' for i in range(len(B))],
                # So that we save more information about each iteration, to visualize later:
                debug_stats=True,
                params=Optimizer.Params(verbose=True, initial_lambda=1e3, lambda_down_factor=1 / 10.0, lambda_upper_bound=1e8, iterations=1000, early_exit_min_reduction=1e-4)
            )
        else:
            optimizer = Optimizer(
                factors=factors,
                optimized_keys=["X", "Y"] + \
                            [f'A[{i}]' for i in range(len(A))],
                # So that we save more information about each iteration, to visualize later:
                debug_stats=False,
                params=Optimizer.Params(verbose=True, initial_lambda=1e3, lambda_down_factor=1 / 10.0, lambda_upper_bound=1e8, iterations=1000, early_exit_min_reduction=1e-4)
            )
        result = optimizer.optimize(initial_values)
        time.sleep(0.1)
        if result.status == Optimizer.Status.SUCCESS:
            print("Optimization successful!")
            self.result = result
        else:
            print("Optimization failed!")
            self.result = None

        return result
    

    def getOptimizedResults(self):
        if self.result is None:
            print("No optimization has been performed yet or optimization failed")
            return None
        X_R = self.result.optimized_values['X'].R.to_rotation_matrix()
        X_t = self.result.optimized_values['X'].t

        Y_R = self.result.optimized_values['Y'].R.to_rotation_matrix()
        Y_t = self.result.optimized_values['Y'].t

        X = np.vstack([np.hstack([X_R, X_t.reshape(3,1)]), np.array([[0,0,0,1]])])
        Y = np.vstack([np.hstack([Y_R, Y_t.reshape(3,1)]), np.array([[0,0,0,1]])])
        return {'X': X, 'Y': Y}
        
solver = AXYBReprojectionOptimizer(camera_T_tag='B', camera_matrix=data['camera_matrix'])

# %%
result = solver.solve(A=A, B=B, X=X, Y=Y, pix_ps=pix_ps, tag_ps=tag_ps)
# Out:
# [2024-01-13 22:50:20.595] [info] LM<sym::Optimize> [iter    0] lambda: 1.000e+03, error prev/linear/new: 251247.064/0.000/361747.750, rel reduction: -0.43981
# [2024-01-13 22:50:20.602] [info] LM<sym::Optimize> [iter    1] lambda: 4.000e+03, error prev/linear/new: 251247.064/0.000/257369.734, rel reduction: -0.02437
# [2024-01-13 22:50:20.608] [info] LM<sym::Optimize> [iter    2] lambda: 1.600e+04, error prev/linear/new: 251247.064/0.000/194352.797, rel reduction: 0.22645
# [2024-01-13 22:50:20.613] [info] LM<sym::Optimize> [iter    3] lambda: 1.600e+03, error prev/linear/new: 194352.796/0.000/655913.562, rel reduction: -2.37486
# [2024-01-13 22:50:20.619] [info] LM<sym::Optimize> [iter    4] lambda: 6.400e+03, error prev/linear/new: 194352.796/0.000/303125.969, rel reduction: -0.55967
# [2024-01-13 22:50:20.624] [info] LM<sym::Optimize> [iter    5] lambda: 2.560e+04, error prev/linear/new: 194352.796/0.000/173847.359, rel reduction: 0.10551
# [2024-01-13 22:50:20.629] [info] LM<sym::Optimize> [iter    6] lambda: 2.560e+03, error prev/linear/new: 173847.361/0.000/176409.328, rel reduction: -0.01474
# [2024-01-13 22:50:20.634] [info] LM<sym::Optimize> [iter    7] lambda: 1.024e+04, error prev/linear/new: 173847.361/0.000/129902.891, rel reduction: 0.25278
# [2024-01-13 22:50:20.640] [info] LM<sym::Optimize> [iter    8] lambda: 1.024e+03, error prev/linear/new: 129902.889/0.000/379663.406, rel reduction: -1.92267
# [2024-01-13 22:50:20.645] [info] LM<sym::Optimize> [iter    9] lambda: 4.096e+03, error prev/linear/new: 129902.889/0.000/190159.906, rel reduction: -0.46386
# [2024-01-13 22:50:20.650] [info] LM<sym::Optimize> [iter   10] lambda: 1.638e+04, error prev/linear/new: 129902.889/0.000/117575.641, rel reduction: 0.09490
# [2024-01-13 22:50:20.656] [info] LM<sym::Optimize> [iter   11] lambda: 1.638e+03, error prev/linear/new: 117575.644/0.000/167683.984, rel reduction: -0.42618
# [2024-01-13 22:50:20.661] [info] LM<sym::Optimize> [iter   12] lambda: 6.554e+03, error prev/linear/new: 117575.644/0.000/186324.844, rel reduction: -0.58472
# [2024-01-13 22:50:20.666] [info] LM<sym::Optimize> [iter   13] lambda: 2.621e+04, error prev/linear/new: 117575.644/0.000/135548.703, rel reduction: -0.15286
# [2024-01-13 22:50:20.672] [info] LM<sym::Optimize> [iter   14] lambda: 1.049e+05, error prev/linear/new: 117575.644/0.000/83693.055, rel reduction: 0.28818
# [2024-01-13 22:50:20.678] [info] LM<sym::Optimize> [iter   15] lambda: 1.049e+04, error prev/linear/new: 83693.055/0.000/145627.688, rel reduction: -0.74002
# [2024-01-13 22:50:20.684] [info] LM<sym::Optimize> [iter   16] lambda: 4.194e+04, error prev/linear/new: 83693.055/0.000/80636.719, rel reduction: 0.03652
# [2024-01-13 22:50:20.689] [info] LM<sym::Optimize> [iter   17] lambda: 4.194e+03, error prev/linear/new: 80636.721/0.000/179276.062, rel reduction: -1.22326
# [2024-01-13 22:50:20.695] [info] LM<sym::Optimize> [iter   18] lambda: 1.678e+04, error prev/linear/new: 80636.721/0.000/152277.469, rel reduction: -0.88844
# [2024-01-13 22:50:20.702] [info] LM<sym::Optimize> [iter   19] lambda: 6.711e+04, error prev/linear/new: 80636.721/0.000/100331.938, rel reduction: -0.24425
# [2024-01-13 22:50:20.708] [info] LM<sym::Optimize> [iter   20] lambda: 2.684e+05, error prev/linear/new: 80636.721/0.000/74442.273, rel reduction: 0.07682
# [2024-01-13 22:50:20.712] [info] LM<sym::Optimize> [iter   21] lambda: 2.684e+04, error prev/linear/new: 74442.274/0.000/131951.391, rel reduction: -0.77253
# [2024-01-13 22:50:20.716] [info] LM<sym::Optimize> [iter   22] lambda: 1.074e+05, error prev/linear/new: 74442.274/0.000/131947.422, rel reduction: -0.77248
# [2024-01-13 22:50:20.722] [info] LM<sym::Optimize> [iter   23] lambda: 4.295e+05, error prev/linear/new: 74442.274/0.000/115077.211, rel reduction: -0.54586
# [2024-01-13 22:50:20.729] [info] LM<sym::Optimize> [iter   24] lambda: 1.718e+06, error prev/linear/new: 74442.274/0.000/92648.828, rel reduction: -0.24457
# [2024-01-13 22:50:20.736] [info] LM<sym::Optimize> [iter   25] lambda: 6.872e+06, error prev/linear/new: 74442.274/0.000/73234.453, rel reduction: 0.01622
# [2024-01-13 22:50:20.742] [info] LM<sym::Optimize> [iter   26] lambda: 6.872e+05, error prev/linear/new: 73234.452/0.000/67929.594, rel reduction: 0.07244
# [2024-01-13 22:50:20.747] [info] LM<sym::Optimize> [iter   27] lambda: 6.872e+04, error prev/linear/new: 67929.594/0.000/95024.609, rel reduction: -0.39887
# [2024-01-13 22:50:20.751] [info] LM<sym::Optimize> [iter   28] lambda: 2.749e+05, error prev/linear/new: 67929.594/0.000/88802.219, rel reduction: -0.30727
# [2024-01-13 22:50:20.757] [info] LM<sym::Optimize> [iter   29] lambda: 1.100e+06, error prev/linear/new: 67929.594/0.000/80561.500, rel reduction: -0.18596
# [2024-01-13 22:50:20.763] [info] LM<sym::Optimize> [iter   30] lambda: 4.398e+06, error prev/linear/new: 67929.594/0.000/69756.922, rel reduction: -0.02690
# [2024-01-13 22:50:20.767] [info] LM<sym::Optimize> [iter   31] lambda: 1.759e+07, error prev/linear/new: 67929.594/0.000/58899.062, rel reduction: 0.13294
# [2024-01-13 22:50:20.772] [info] LM<sym::Optimize> [iter   32] lambda: 1.759e+06, error prev/linear/new: 58899.064/0.000/60558.930, rel reduction: -0.02818
# [2024-01-13 22:50:20.777] [info] LM<sym::Optimize> [iter   33] lambda: 7.037e+06, error prev/linear/new: 58899.064/0.000/58870.852, rel reduction: 0.00048
# [2024-01-13 22:50:20.781] [info] LM<sym::Optimize> [iter   34] lambda: 7.037e+05, error prev/linear/new: 58870.853/0.000/61228.875, rel reduction: -0.04005
# [2024-01-13 22:50:20.786] [info] LM<sym::Optimize> [iter   35] lambda: 2.815e+06, error prev/linear/new: 58870.853/0.000/59358.711, rel reduction: -0.00829
# [2024-01-13 22:50:20.791] [info] LM<sym::Optimize> [iter   36] lambda: 1.126e+07, error prev/linear/new: 58870.853/0.000/57115.578, rel reduction: 0.02982
# [2024-01-13 22:50:20.797] [info] LM<sym::Optimize> [iter   37] lambda: 1.126e+06, error prev/linear/new: 57115.578/0.000/57203.359, rel reduction: -0.00154
# [2024-01-13 22:50:20.803] [info] LM<sym::Optimize> [iter   38] lambda: 4.504e+06, error prev/linear/new: 57115.578/0.000/57103.680, rel reduction: 0.00021
# [2024-01-13 22:50:20.811] [info] LM<sym::Optimize> [iter   39] lambda: 4.504e+05, error prev/linear/new: 57103.681/0.000/60095.918, rel reduction: -0.05240
# [2024-01-13 22:50:20.816] [info] LM<sym::Optimize> [iter   40] lambda: 1.801e+06, error prev/linear/new: 57103.681/0.000/58417.344, rel reduction: -0.02300
# [2024-01-13 22:50:20.822] [info] LM<sym::Optimize> [iter   41] lambda: 7.206e+06, error prev/linear/new: 57103.681/0.000/56750.703, rel reduction: 0.00618
# [2024-01-13 22:50:20.828] [info] LM<sym::Optimize> [iter   42] lambda: 7.206e+05, error prev/linear/new: 56750.705/0.000/57091.113, rel reduction: -0.00600
# [2024-01-13 22:50:20.832] [info] LM<sym::Optimize> [iter   43] lambda: 2.882e+06, error prev/linear/new: 56750.705/0.000/57066.211, rel reduction: -0.00556
# [2024-01-13 22:50:20.838] [info] LM<sym::Optimize> [iter   44] lambda: 1.153e+07, error prev/linear/new: 56750.705/0.000/55875.480, rel reduction: 0.01542
# [2024-01-13 22:50:20.844] [info] LM<sym::Optimize> [iter   45] lambda: 1.153e+06, error prev/linear/new: 55875.479/0.000/56128.426, rel reduction: -0.00453
# [2024-01-13 22:50:20.849] [info] LM<sym::Optimize> [iter   46] lambda: 4.612e+06, error prev/linear/new: 55875.479/0.000/55789.941, rel reduction: 0.00153
# [2024-01-13 22:50:20.854] [info] LM<sym::Optimize> [iter   47] lambda: 4.612e+05, error prev/linear/new: 55789.943/0.000/55402.871, rel reduction: 0.00694
# [2024-01-13 22:50:20.858] [info] LM<sym::Optimize> [iter   48] lambda: 4.612e+04, error prev/linear/new: 55402.872/0.000/75107.430, rel reduction: -0.35566
# [2024-01-13 22:50:20.863] [info] LM<sym::Optimize> [iter   49] lambda: 1.845e+05, error prev/linear/new: 55402.872/0.000/64187.750, rel reduction: -0.15856
# [2024-01-13 22:50:20.870] [info] LM<sym::Optimize> [iter   50] lambda: 7.379e+05, error prev/linear/new: 55402.872/0.000/58840.727, rel reduction: -0.06205
# [2024-01-13 22:50:20.879] [info] LM<sym::Optimize> [iter   51] lambda: 2.951e+06, error prev/linear/new: 55402.872/0.000/56369.570, rel reduction: -0.01745
# [2024-01-13 22:50:20.885] [info] LM<sym::Optimize> [iter   52] lambda: 1.181e+07, error prev/linear/new: 55402.872/0.000/54705.387, rel reduction: 0.01259
# [2024-01-13 22:50:20.891] [info] LM<sym::Optimize> [iter   53] lambda: 1.181e+06, error prev/linear/new: 54705.389/0.000/54792.477, rel reduction: -0.00159
# [2024-01-13 22:50:20.898] [info] LM<sym::Optimize> [iter   54] lambda: 4.722e+06, error prev/linear/new: 54705.389/0.000/54638.504, rel reduction: 0.00122
# [2024-01-13 22:50:20.903] [info] LM<sym::Optimize> [iter   55] lambda: 4.722e+05, error prev/linear/new: 54638.503/0.000/55264.434, rel reduction: -0.01146
# [2024-01-13 22:50:20.911] [info] LM<sym::Optimize> [iter   56] lambda: 1.889e+06, error prev/linear/new: 54638.503/0.000/54950.766, rel reduction: -0.00572
# [2024-01-13 22:50:20.918] [info] LM<sym::Optimize> [iter   57] lambda: 7.556e+06, error prev/linear/new: 54638.503/0.000/54416.680, rel reduction: 0.00406
# [2024-01-13 22:50:20.924] [info] LM<sym::Optimize> [iter   58] lambda: 7.556e+05, error prev/linear/new: 54416.679/0.000/54347.027, rel reduction: 0.00128
# [2024-01-13 22:50:20.929] [info] LM<sym::Optimize> [iter   59] lambda: 7.556e+04, error prev/linear/new: 54347.029/0.000/55965.078, rel reduction: -0.02977
# [2024-01-13 22:50:20.934] [info] LM<sym::Optimize> [iter   60] lambda: 3.022e+05, error prev/linear/new: 54347.029/0.000/55113.613, rel reduction: -0.01411
# [2024-01-13 22:50:20.939] [info] LM<sym::Optimize> [iter   61] lambda: 1.209e+06, error prev/linear/new: 54347.029/0.000/54865.617, rel reduction: -0.00954
# [2024-01-13 22:50:20.945] [info] LM<sym::Optimize> [iter   62] lambda: 4.836e+06, error prev/linear/new: 54347.029/0.000/54308.895, rel reduction: 0.00070
# [2024-01-13 22:50:20.950] [info] LM<sym::Optimize> [iter   63] lambda: 4.836e+05, error prev/linear/new: 54308.894/0.000/54536.152, rel reduction: -0.00418
# [2024-01-13 22:50:20.956] [info] LM<sym::Optimize> [iter   64] lambda: 1.934e+06, error prev/linear/new: 54308.894/0.000/54585.359, rel reduction: -0.00509
# [2024-01-13 22:50:20.962] [info] LM<sym::Optimize> [iter   65] lambda: 7.737e+06, error prev/linear/new: 54308.894/0.000/54018.617, rel reduction: 0.00534
# [2024-01-13 22:50:20.967] [info] LM<sym::Optimize> [iter   66] lambda: 7.737e+05, error prev/linear/new: 54018.617/0.000/54249.914, rel reduction: -0.00428
# [2024-01-13 22:50:20.972] [info] LM<sym::Optimize> [iter   67] lambda: 3.095e+06, error prev/linear/new: 54018.617/0.000/54087.555, rel reduction: -0.00128
# [2024-01-13 22:50:20.977] [info] LM<sym::Optimize> [iter   68] lambda: 1.238e+07, error prev/linear/new: 54018.617/0.000/53627.102, rel reduction: 0.00725
# [2024-01-13 22:50:20.983] [info] LM<sym::Optimize> [iter   69] lambda: 1.238e+06, error prev/linear/new: 53627.101/0.000/53526.000, rel reduction: 0.00189
# [2024-01-13 22:50:20.988] [info] LM<sym::Optimize> [iter   70] lambda: 1.238e+05, error prev/linear/new: 53525.999/0.000/52974.914, rel reduction: 0.01030
# [2024-01-13 22:50:20.993] [info] LM<sym::Optimize> [iter   71] lambda: 1.238e+04, error prev/linear/new: 52974.914/0.000/62770.281, rel reduction: -0.18491
# [2024-01-13 22:50:20.998] [info] LM<sym::Optimize> [iter   72] lambda: 4.952e+04, error prev/linear/new: 52974.914/0.000/58533.598, rel reduction: -0.10493
# [2024-01-13 22:50:21.003] [info] LM<sym::Optimize> [iter   73] lambda: 1.981e+05, error prev/linear/new: 52974.914/0.000/55612.012, rel reduction: -0.04978
# [2024-01-13 22:50:21.009] [info] LM<sym::Optimize> [iter   74] lambda: 7.923e+05, error prev/linear/new: 52974.914/0.000/53556.750, rel reduction: -0.01098
# [2024-01-13 22:50:21.013] [info] LM<sym::Optimize> [iter   75] lambda: 3.169e+06, error prev/linear/new: 52974.914/0.000/52718.070, rel reduction: 0.00485
# [2024-01-13 22:50:21.020] [info] LM<sym::Optimize> [iter   76] lambda: 3.169e+05, error prev/linear/new: 52718.072/0.000/59629.059, rel reduction: -0.13109
# [2024-01-13 22:50:21.025] [info] LM<sym::Optimize> [iter   77] lambda: 1.268e+06, error prev/linear/new: 52718.072/0.000/56680.746, rel reduction: -0.07517
# [2024-01-13 22:50:21.031] [info] LM<sym::Optimize> [iter   78] lambda: 5.071e+06, error prev/linear/new: 52718.072/0.000/53806.977, rel reduction: -0.02066
# [2024-01-13 22:50:21.038] [info] LM<sym::Optimize> [iter   79] lambda: 2.028e+07, error prev/linear/new: 52718.072/0.000/51628.500, rel reduction: 0.02067
# [2024-01-13 22:50:21.044] [info] LM<sym::Optimize> [iter   80] lambda: 2.028e+06, error prev/linear/new: 51628.500/0.000/51585.914, rel reduction: 0.00082
# [2024-01-13 22:50:21.050] [info] LM<sym::Optimize> [iter   81] lambda: 2.028e+05, error prev/linear/new: 51585.914/0.000/51528.590, rel reduction: 0.00111
# [2024-01-13 22:50:21.054] [info] LM<sym::Optimize> [iter   82] lambda: 2.028e+04, error prev/linear/new: 51528.591/0.000/53257.242, rel reduction: -0.03355
# [2024-01-13 22:50:21.058] [info] LM<sym::Optimize> [iter   83] lambda: 8.113e+04, error prev/linear/new: 51528.591/0.000/53575.430, rel reduction: -0.03972
# [2024-01-13 22:50:21.064] [info] LM<sym::Optimize> [iter   84] lambda: 3.245e+05, error prev/linear/new: 51528.591/0.000/52581.367, rel reduction: -0.02043
# [2024-01-13 22:50:21.069] [info] LM<sym::Optimize> [iter   85] lambda: 1.298e+06, error prev/linear/new: 51528.591/0.000/51711.008, rel reduction: -0.00354
# [2024-01-13 22:50:21.074] [info] LM<sym::Optimize> [iter   86] lambda: 5.192e+06, error prev/linear/new: 51528.591/0.000/51111.695, rel reduction: 0.00809
# [2024-01-13 22:50:21.079] [info] LM<sym::Optimize> [iter   87] lambda: 5.192e+05, error prev/linear/new: 51111.695/0.000/51479.586, rel reduction: -0.00720
# [2024-01-13 22:50:21.084] [info] LM<sym::Optimize> [iter   88] lambda: 2.077e+06, error prev/linear/new: 51111.695/0.000/51305.070, rel reduction: -0.00378
# [2024-01-13 22:50:21.089] [info] LM<sym::Optimize> [iter   89] lambda: 8.308e+06, error prev/linear/new: 51111.695/0.000/50818.191, rel reduction: 0.00574
# [2024-01-13 22:50:21.094] [info] LM<sym::Optimize> [iter   90] lambda: 8.308e+05, error prev/linear/new: 50818.191/0.000/50918.531, rel reduction: -0.00197
# [2024-01-13 22:50:21.100] [info] LM<sym::Optimize> [iter   91] lambda: 3.323e+06, error prev/linear/new: 50818.191/0.000/50739.508, rel reduction: 0.00155
# [2024-01-13 22:50:21.105] [info] LM<sym::Optimize> [iter   92] lambda: 3.323e+05, error prev/linear/new: 50739.507/0.000/50867.195, rel reduction: -0.00252
# [2024-01-13 22:50:21.110] [info] LM<sym::Optimize> [iter   93] lambda: 1.329e+06, error prev/linear/new: 50739.507/0.000/50866.215, rel reduction: -0.00250
# [2024-01-13 22:50:21.114] [info] LM<sym::Optimize> [iter   94] lambda: 5.317e+06, error prev/linear/new: 50739.507/0.000/50661.227, rel reduction: 0.00154
# [2024-01-13 22:50:21.120] [info] LM<sym::Optimize> [iter   95] lambda: 5.317e+05, error prev/linear/new: 50661.227/0.000/50713.898, rel reduction: -0.00104
# [2024-01-13 22:50:21.125] [info] LM<sym::Optimize> [iter   96] lambda: 2.127e+06, error prev/linear/new: 50661.227/0.000/50652.051, rel reduction: 0.00018
# [2024-01-13 22:50:21.131] [info] LM<sym::Optimize> [iter   97] lambda: 2.127e+05, error prev/linear/new: 50652.051/0.000/50852.660, rel reduction: -0.00396
# [2024-01-13 22:50:21.136] [info] LM<sym::Optimize> [iter   98] lambda: 8.507e+05, error prev/linear/new: 50652.051/0.000/50823.594, rel reduction: -0.00339
# [2024-01-13 22:50:21.142] [info] LM<sym::Optimize> [iter   99] lambda: 3.403e+06, error prev/linear/new: 50652.051/0.000/50654.098, rel reduction: -0.00004
# [2024-01-13 22:50:21.148] [info] LM<sym::Optimize> [iter  100] lambda: 1.361e+07, error prev/linear/new: 50652.051/0.000/50387.711, rel reduction: 0.00522
# [2024-01-13 22:50:21.154] [info] LM<sym::Optimize> [iter  101] lambda: 1.361e+06, error prev/linear/new: 50387.712/0.000/50328.719, rel reduction: 0.00117
# [2024-01-13 22:50:21.159] [info] LM<sym::Optimize> [iter  102] lambda: 1.361e+05, error prev/linear/new: 50328.718/0.000/50047.164, rel reduction: 0.00559
# [2024-01-13 22:50:21.165] [info] LM<sym::Optimize> [iter  103] lambda: 1.361e+04, error prev/linear/new: 50047.165/0.000/59450.176, rel reduction: -0.18788
# [2024-01-13 22:50:21.170] [info] LM<sym::Optimize> [iter  104] lambda: 5.445e+04, error prev/linear/new: 50047.165/0.000/53819.543, rel reduction: -0.07538
# [2024-01-13 22:50:21.175] [info] LM<sym::Optimize> [iter  105] lambda: 2.178e+05, error prev/linear/new: 50047.165/0.000/51224.250, rel reduction: -0.02352
# [2024-01-13 22:50:21.180] [info] LM<sym::Optimize> [iter  106] lambda: 8.711e+05, error prev/linear/new: 50047.165/0.000/50123.457, rel reduction: -0.00152
# [2024-01-13 22:50:21.186] [info] LM<sym::Optimize> [iter  107] lambda: 3.484e+06, error prev/linear/new: 50047.165/0.000/49840.406, rel reduction: 0.00413
# [2024-01-13 22:50:21.191] [info] LM<sym::Optimize> [iter  108] lambda: 3.484e+05, error prev/linear/new: 49840.408/0.000/49868.305, rel reduction: -0.00056
# [2024-01-13 22:50:21.198] [info] LM<sym::Optimize> [iter  109] lambda: 1.394e+06, error prev/linear/new: 49840.408/0.000/49909.324, rel reduction: -0.00138
# [2024-01-13 22:50:21.204] [info] LM<sym::Optimize> [iter  110] lambda: 5.575e+06, error prev/linear/new: 49840.408/0.000/49730.633, rel reduction: 0.00220
# [2024-01-13 22:50:21.210] [info] LM<sym::Optimize> [iter  111] lambda: 5.575e+05, error prev/linear/new: 49730.634/0.000/49826.941, rel reduction: -0.00194
# [2024-01-13 22:50:21.215] [info] LM<sym::Optimize> [iter  112] lambda: 2.230e+06, error prev/linear/new: 49730.634/0.000/49668.043, rel reduction: 0.00126
# [2024-01-13 22:50:21.222] [info] LM<sym::Optimize> [iter  113] lambda: 2.230e+05, error prev/linear/new: 49668.044/0.000/49732.754, rel reduction: -0.00130
# [2024-01-13 22:50:21.228] [info] LM<sym::Optimize> [iter  114] lambda: 8.920e+05, error prev/linear/new: 49668.044/0.000/49759.777, rel reduction: -0.00185
# [2024-01-13 22:50:21.234] [info] LM<sym::Optimize> [iter  115] lambda: 3.568e+06, error prev/linear/new: 49668.044/0.000/49635.223, rel reduction: 0.00066
# [2024-01-13 22:50:21.239] [info] LM<sym::Optimize> [iter  116] lambda: 3.568e+05, error prev/linear/new: 49635.224/0.000/49749.227, rel reduction: -0.00230
# [2024-01-13 22:50:21.244] [info] LM<sym::Optimize> [iter  117] lambda: 1.427e+06, error prev/linear/new: 49635.224/0.000/49633.336, rel reduction: 0.00004
# Optimization successful!

# %%
result.status
# result.error()
# result.optimized_values['X']
solver.getOptimizedResults()
# Out:
# {'X': array([[-0.442, -0.622, -0.646,  0.006],
#         [-0.695, -0.217,  0.685, -0.014],
#         [-0.567,  0.752, -0.337,  0.   ],
#         [ 0.   ,  0.   ,  0.   ,  1.   ]]),
#  'Y': array([[-0.985,  0.005, -0.17 , -0.019],
#         [ 0.17 ,  0.076, -0.983, -0.36 ],
#         [ 0.008, -0.997, -0.075,  0.096],
#         [ 0.   ,  0.   ,  0.   ,  1.   ]])}

# %% [markdown]
# ## Visualize Errors Before Optimization

# %%
import numpy as np
import matplotlib.pyplot as plt

with open('b1-d455-dataset.pkl', 'rb') as f:
    data = pickle.load(f)


imgs = data['apriltag_imgs_raw']
corners = [info['corners'] for info in data['apriltag_info']]
A = data['A_list']
B = data['B_list']
X = data['X']
Y = data['Y']
K = data['camera_matrix']


tag_size = 0.172
tag_corners = np.array([[-tag_size/2, tag_size/2, 0],
                        [ tag_size/2, tag_size/2, 0],
                        [ tag_size/2, -tag_size/2, 0],
                        [-tag_size/2,  -tag_size/2, 0]])
tag_corners = np.hstack([tag_corners, np.ones((4,1))]).T

# %%
for i in range(len(imgs)):
    print((A[i]@X@np.linalg.inv(Y@B[i]))[:3,-1])
# Out:
# [ 0.096  0.096 -0.078]
# [ 0.103  0.175 -0.097]
# [ 0.128 -0.066  0.026]
# [ 0.02  -0.144 -0.151]
# [-0.272 -0.089  0.268]
# [-0.098  0.015  0.027]

# %%
errors = []
# for n in range(len(corners)):
for n in [0]:
    pixel_pos = corners[n].T
    cam_T_tag_est = np.linalg.inv(Y)@A[n]@X
    # cam_T_tag_est = B[n]

    cam_p = cam_T_tag_est@tag_corners
    pixel_pos_hat = K@cam_p[0:3,:]
    pixel_pos_hat = (pixel_pos_hat/pixel_pos_hat[2,:])[0:2,:]
    e = (pixel_pos-pixel_pos_hat).mean(axis=1)
    errors.append(e)
errors = np.array(errors)
plt.imshow(imgs[n])
plt.plot(pixel_pos[0,:], pixel_pos[1,:], 'r.')
plt.plot(pixel_pos_hat[0,:], pixel_pos_hat[1,:], 'b.')
# disable ticks
plt.xticks([])
plt.yticks([])
# plt.savefig('results/reprojection_before_opt.png', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.plot(errors[:,0],errors[:,1], '*')
plt.title('reprojection error (pixels)')
plt.xlabel('X error (pixels)')
plt.ylabel('Y error (pixels)')
plt.grid(True)
# disable ticks
plt.savefig('results/reprojection_error_before_opt.png', bbox_inches='tight', pad_inches=0)
plt.show()

# %% [markdown]
# ## Visualization After Optimization

# %%
result = solver.getOptimizedResults()
X = result['X']
Y = result['Y']

# %%
import numpy as np
import matplotlib.pyplot as plt

imgs = data['apriltag_imgs_udist']
corners = [info['corners'] for info in data['apriltag_info']]
vicon_T_marker = data['A_list']
camera_T_tag = data['B_list']
marker_T_tag = result['X']
vicon_T_cam = result['Y']
K = data['camera_matrix']
cam_T_vicon = np.linalg.inv(vicon_T_cam)

tag_size = 0.1285
tag_corners = np.array([[-tag_size/2, tag_size/2, 0],
                        [ tag_size/2, tag_size/2, 0],
                        [ tag_size/2, -tag_size/2, 0],
                        [-tag_size/2,  -tag_size/2, 0]])
tag_corners = np.hstack([tag_corners, np.ones((4,1))]).T

# %%
errors = []
for n in range(len(corners)):
    pixel_pos = corners[n].T
    cam_p = cam_T_vicon@vicon_T_marker[n]@marker_T_tag@tag_corners
    pixel_pos_hat = K@cam_p[0:3,:]
    pixel_pos_hat = (pixel_pos_hat/pixel_pos_hat[2,:])[0:2,:]
    e = (pixel_pos-pixel_pos_hat).mean(axis=1)
    errors.append(e)
errors = np.array(errors)
plt.imshow(imgs[n])
plt.plot(pixel_pos[0,:], pixel_pos[1,:], 'r.')
plt.plot(pixel_pos_hat[0,:], pixel_pos_hat[1,:], 'b.')
# disable ticks
plt.xticks([])
plt.yticks([])
# plt.savefig('results/reprojection_after_opt.png', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
plt.plot(errors[:,0],errors[:,1], '*')
plt.title('reprojection error (pixels)')
plt.xlabel('X error (pixels)')
plt.ylabel('Y error (pixels)')
plt.grid(True)
plt.savefig('results/reprojection_error_after_opt.png', bbox_inches='tight', pad_inches=0)
plt.show()
